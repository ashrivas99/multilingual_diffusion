# %%
# !pip install -q --upgrade huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.3/489.3 kB 31.7 MB/s eta 0:00:00

# %%
# accelerate==0.29.3
# datasets==2.19.0
# diffusers==0.28.0
# einops==0.8.0
# Pillow==10.3.0
# torch==2.2.0
# torchvision==0.17.0
# tqdm==4.66.2
# transformers==4.40.1

# !pip install pillow torchmetrics torchmetrics[image] torch-fidelity
# !pip install -q --upgrade datasets fsspec
#  or, if you want to pin exactly the fixed version:
# !pip install -q datasets==2.14.7 fsspec==2023.9.2
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Collecting torchmetrics
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting torch-fidelity
#   Downloading torch_fidelity-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: torchvision>=0.15.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics[image]) (0.21.0+cu124)
# Requirement already satisfied: scipy>1.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics[image]) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch-fidelity) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 46.3 MB/s eta 0:00:00
# Downloading torch_fidelity-0.3.0-py3-none-any.whl (37 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, torch-fidelity
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torch-fidelity-0.3.0 torchmetrics-1.7.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 20.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rm -rf data

# %% [markdown]
# Here iss the formatted Markdown table:
#
# Script	Unicode	Character	Caption
# Latin	U+0041	A	“A”
# 	U+0042	B	“B”
# 	U+0044	D	“D”
# 	U+0047	G	“G”
# 	U+0057	W	“W”
# Arabic	U+0641	ف	“faa”
# 	U+0642	ق	“qaaf”
# 	U+063A	غ	“ghayn”
# 	U+0644	ل	“laam”
# 	U+0645	م	“meem”
# Devanagari	U+0915	क	“ka”
# 	U+0932	ल	“la”
# 	U+0950	ॐ	“om”
# 	U+0917	ग	“ga”
# 	U+092E	म	“ma”

# %% [markdown]
# # Get Arabic Characters

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi # run this cell twice if the import fails
import zipfile

# ─── 1) Configure your Kaggle credentials in-process ──────────────────────────────
os.environ['KAGGLE_USERNAME'] = 'adityaks99'       # replace with your username
os.environ['KAGGLE_KEY']      = 'c5cb1c09b368431d2e753f573b91cc79'  # your API key

# ─── 2) Authenticate to Kaggle ───────────────────────────────────────────────────
api = KaggleApi()
api.authenticate()  # raises if creds are invalid :contentReference[oaicite:0]{index=0}

# ─── 3) Download the dataset ZIP and auto-unzip ──────────────────────────────────
dataset_slug = 'hossammbalaha/hmbd-v1-arabic-handwritten-characters-dataset'
target_dir   = 'HMBD_v1'  # local directory to hold PNGs

# This fetches and extracts all files into `target_dir/` :contentReference[oaicite:1]{index=1}
api.dataset_download_files(
    dataset_slug,
    path=target_dir,
    unzip=True,
    force=True,   # overwrite existing files if re-running
    quiet=False
)

# ─── 4) (Optional) Verify contents ───────────────────────────────────────────────
# After the above, you should see subfolders named by class, each containing 300×300 PNGs.
for root, dirs, files in os.walk(target_dir):
    if files:
        print(f'Found {len(files)} files in {root}')
        break
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hossammbalaha/hmbd-v1-arabic-handwritten-characters-dataset
# Downloading hmbd-v1-arabic-handwritten-characters-dataset.zip to HMBD_v1
# 100%|██████████| 169M/169M [00:00<00:00, 1.31GB/s]
# Found 4 files in HMBD_v1

# %%
#!/usr/bin/env python3
"""
Automated pipeline to:
1. Enumerate all Arabic‐script Unicode code points
2. Generate a CSV with Unicode, character, and name
3. Download a set of up-to-date, canonical Arabic fonts
4. Incorporate a locally-downloaded Scheherazade ZIP
5. Extract all TTFs
6. Render each character in each font to 128×128 PNGs
"""

import unicodedata
import csv
import logging
from pathlib import Path
import requests
import zipfile
from PIL import Image, ImageDraw, ImageFont

# -----------------------------------------------------------------------------
# 1) Configuration
# -----------------------------------------------------------------------------

# Unicode blocks covering Arabic script, supplements, and presentation forms
UNICODE_BLOCKS = [
    (0x0600, 0x06FF),   # Arabic
    (0x0750, 0x077F),   # Arabic Supplement
    (0x08A0, 0x08FF),   # Arabic Extended-A
    (0xFB50, 0xFDFF),   # Arabic Presentation Forms-A
    (0xFE70, 0xFEFF),   # Arabic Presentation Forms-B
]

# Fonts to download (static TTFs)
FONTS = {
    "NotoNaskhArabic[wght].ttf":
        "https://github.com/google/fonts/raw/main/ofl/notonaskharabic/NotoNaskhArabic%5Bwght%5D.ttf",
    "Amiri-Regular.ttf":
        "https://github.com/google/fonts/raw/main/ofl/amiri/Amiri-Regular.ttf",
    "Lateef-Regular.ttf":
        "https://github.com/google/fonts/raw/main/ofl/lateef/Lateef-Regular.ttf",
    "Harmattan-Regular.ttf":
        "https://github.com/google/fonts/raw/main/ofl/harmattan/Harmattan-Regular.ttf",
}


# Image settings
IMG_SIZE  = (128, 128)
FONT_SIZE = 100

# -----------------------------------------------------------------------------
# 2) Paths & Logging
# -----------------------------------------------------------------------------

BASE_DIR   = Path.cwd()
DATA_DIR   = BASE_DIR / "data_generation"
FONTS_DIR  = DATA_DIR / "fonts"
CSV_PATH   = DATA_DIR / "arabic_chars.csv"
IMAGES_DIR = DATA_DIR / "images"


# Path to your manually-downloaded Scheherazade ZIP
LOCAL_SCHEHERAZADE_ZIP = Path(
    f"{DATA_DIR}/manually_downloaded_fonts/Scheherazade_New.zip"
)

for d in (DATA_DIR, FONTS_DIR, IMAGES_DIR):
    d.mkdir(parents=True, exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

# -----------------------------------------------------------------------------
# 3) Step 1: Generate CSV of Arabic characters
# -----------------------------------------------------------------------------

logging.info("Step 1: Generating CSV of Arabic‐script characters...")

with CSV_PATH.open("w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Unicode", "Character", "Name"])
    for start, end in UNICODE_BLOCKS:
        for cp in range(start, end + 1):
            char = chr(cp)
            name = unicodedata.name(char, "")
            if name.startswith("ARABIC"):
                writer.writerow([f"U+{cp:04X}", char, name])

logging.info(f"  • CSV saved to {CSV_PATH}")

# -----------------------------------------------------------------------------
# 4) Step 2: Download fonts
# -----------------------------------------------------------------------------

logging.info("Step 2: Downloading fonts from the web...")

for fname, url in FONTS.items():
    dest = FONTS_DIR / fname
    if dest.exists():
        logging.info(f"  • {fname} already exists, skipping")
        continue
    logging.info(f"  • Downloading {fname}")
    resp = requests.get(url)
    resp.raise_for_status()
    dest.write_bytes(resp.content)
    logging.info(f"    → Saved to {dest}")

# -----------------------------------------------------------------------------
# 5) Step 3: Incorporate local Scheherazade ZIP
# -----------------------------------------------------------------------------

if LOCAL_SCHEHERAZADE_ZIP.exists():
    logging.info("Step 3: Extracting local Scheherazade ZIP...")
    with zipfile.ZipFile(LOCAL_SCHEHERAZADE_ZIP, 'r') as zf:
        for member in zf.namelist():
            if member.lower().endswith(".ttf"):
                # extract into fonts directory
                target = FONTS_DIR / Path(member).name
                with zf.open(member) as src, target.open('wb') as dst:
                    dst.write(src.read())
                logging.info(f"    → Extracted {target.name}")
else:
    logging.warning(f"Local Scheherazade ZIP not found at {LOCAL_SCHEHERAZADE_ZIP}")

# -----------------------------------------------------------------------------
# 6) Step 4: Render images for each font  – with “glyph-supported” check
# -----------------------------------------------------------------------------
logging.info("Step 4: Rendering images for each font…")

SCRATCH = 256          # temporary big canvas
TARGET  = 128          # final PNG size
MISSING = {}           # font_name → count of unsupported glyphs

def glyph_supported(ch: str, ft: ImageFont.FreeTypeFont) -> bool:
    """Return True if this font has a real outline for *ch* (not fallback □)."""
    tmp = Image.new("L", (64, 64), 255)
    dr  = ImageDraw.Draw(tmp)
    dr.text((0,0), ch, font=ft, fill=0)
    img_char = tmp.tobytes()

    tmp2 = Image.new("L", (64, 64), 255)
    dr2  = ImageDraw.Draw(tmp2)
    dr2.text((0,0), "�", font=ft, fill=0)
    img_repl = tmp2.tobytes()
    return img_char != img_repl

# Load CSV once
with CSV_PATH.open("r", encoding="utf-8") as csvfile:
    records = list(csv.DictReader(csvfile))

# Collect all TTF / OTFs
font_files = sorted(f for f in FONTS_DIR.iterdir()
                    if f.suffix.lower() in {".ttf", ".otf"})

for font_file in font_files:
    font_name = font_file.stem
    out_dir   = IMAGES_DIR / font_name
    out_dir.mkdir(exist_ok=True)

    logging.info(f"  • Rendering with font: {font_name}")
    font = ImageFont.truetype(str(font_file), FONT_SIZE)
    missing = 0

    for row in records:
        code = row["Unicode"]      # e.g. "U+0621"
        char = row["Character"]
        out  = out_dir / f"{font_name}_{code}.png"
        if out.exists():
            continue

        if not glyph_supported(char, font):
            missing += 1
            continue

        # 1. draw glyph centred on big scratch canvas
        scratch = Image.new("L", (SCRATCH, SCRATCH), 255)
        dr      = ImageDraw.Draw(scratch)
        dr.text((SCRATCH/2, SCRATCH/2), char, font=font, fill=0, anchor="mm")

        # 2. tight-crop & 3. scale to 128 keeping aspect
        bbox = scratch.getbbox()
        if not bbox:
            missing += 1
            continue
        glyph = scratch.crop(bbox)
        g_w, g_h = glyph.size
        scale = min(TARGET / g_w, TARGET / g_h)
        glyph = glyph.resize((int(g_w*scale), int(g_h*scale)), Image.LANCZOS)

        # 4. paste on final 128×128 white canvas
        final = Image.new("RGB", (TARGET, TARGET), "white")
        x = (TARGET - glyph.width) // 2
        y = (TARGET - glyph.height) // 2
        final.paste(Image.merge("RGB", (glyph,)*3), (x, y))
        final.save(out)

    total = len(records)
    drawn = total - missing
    MISSING[font_name] = missing
    logging.info(f"    → {drawn}/{total} glyphs rendered "
                 f"({missing} unsupported)")

logging.info("✅ Pipeline complete!")
for fname, miss in MISSING.items():
    logging.info(f"   • {fname}: {miss} unsupported glyphs")
logging.info(f" • CSV:    {CSV_PATH}")
logging.info(f" • Fonts:  {FONTS_DIR}")
logging.info(f" • Images: {IMAGES_DIR}")
# Out:
# WARNING:root:Local Scheherazade ZIP not found at /content/data_generation/manually_downloaded_fonts/Scheherazade_New.zip

# %%
from PIL import Image, UnidentifiedImageError
import os

data_root = "/content/HMBD_v1/Dataset"
bad_files = []
removed_dirs = []

# 1) Identify and delete unreadable images
for root, _, files in os.walk(data_root):
    for fname in files:
        path = os.path.join(root, fname)
        try:
            # verify() reads header only; raises if format unrecognized :contentReference[oaicite:0]{index=0}
            with Image.open(path) as img:
                img.verify()
        except (UnidentifiedImageError, IOError):
            bad_files.append(path)
            os.remove(path)  # delete the corrupted/mis-formatted file :contentReference[oaicite:1]{index=1}
            print(f"Removed unreadable image: {path}")

# 2) Remove any now-empty directories (walk bottom-up) :contentReference[oaicite:2]{index=2}
for root, dirs, files in os.walk(data_root, topdown=False):
    # if no files and no subdirs remain, delete this dir
    if not dirs and not files:
        os.rmdir(root)
        removed_dirs.append(root)
        print(f"Removed empty directory: {root}")

# 3) Print summary
print("\n===== Cleanup Summary =====")
print(f"Total unreadable images removed: {len(bad_files)}")
print(f"Total empty directories removed: {len(removed_dirs)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00064_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00075_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00110_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00014_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00012_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00105_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00086_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00052_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00115_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00120_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00022_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00119_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00018_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00119_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00047_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00001_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00066_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00048_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00112_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00006_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00089_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00029_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00068_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00023_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00084_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00037_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00068_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00002_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00090_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00018_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00085_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00125_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00004_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00049_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00107_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00037_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00013_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00035_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00087_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00055_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00063_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00090_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00019_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00073_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00063_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00053_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00107_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00114_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00042_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00076_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00017_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00017_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00108_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00040_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00015_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00086_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00083_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00108_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00036_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00037_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00091_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00012_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00069_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00122_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00020_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00099_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00006_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00110_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00118_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00029_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00083_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00122_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00046_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00043_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00093_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00106_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00120_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00021_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00061_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00031_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00020_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00067_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00082_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00100_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00056_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00018_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00033_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00003_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00062_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00115_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00105_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00019_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00074_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00075_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00050_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00051_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00088_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00035_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00002_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00035_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00056_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00008_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00033_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00042_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00028_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00020_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00038_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00004_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00057_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00093_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00085_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00072_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00068_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00007_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00124_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00094_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00073_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00078_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00039_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00095_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00086_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00060_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00069_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00059_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00103_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00057_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00026_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00100_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00061_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00007_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00067_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00030_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00058_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00055_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00031_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00028_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00080_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00010_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00080_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00051_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00021_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00091_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00070_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00046_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00079_Khaa_Isolated_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00023_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00117_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00054_Khaa_Isolated_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00008_Khaa_Isolated_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Khaa_Isolated/AHCR_00117_Khaa_Isolated_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00062_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00123_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00005_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00021_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00003_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00111_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00078_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00001_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00106_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00047_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00073_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00119_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00008_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00035_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00043_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00032_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00050_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00081_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00100_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00067_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00040_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00047_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00042_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00023_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00073_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00003_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00077_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00067_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00025_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00091_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00077_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00021_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00094_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00053_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00021_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00033_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00039_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00093_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00072_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00046_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00019_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00089_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00049_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00048_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00042_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00086_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00122_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00025_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00023_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00039_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00031_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00084_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00029_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00009_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00041_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00090_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00083_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00103_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00050_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00085_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00064_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00088_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00001_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00069_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00049_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00060_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00021_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00040_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00069_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00044_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00059_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00082_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00035_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00106_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00045_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00114_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00080_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00032_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00103_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00105_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00004_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00046_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00101_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00013_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00121_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00094_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00114_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00117_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00085_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00020_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00013_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00106_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00119_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00087_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00092_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00110_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00070_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00109_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00014_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00100_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00048_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00047_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00049_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00066_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00124_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00046_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00037_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00086_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00043_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00098_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00029_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00105_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00083_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00070_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00056_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00024_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00024_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00010_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00033_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00075_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00059_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00103_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00018_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00024_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00088_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00074_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00013_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00105_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00125_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00088_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00079_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00044_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00047_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00066_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00031_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00113_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00007_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00118_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00034_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00022_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00006_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00055_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00052_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00037_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00016_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00089_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00071_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00004_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00100_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00051_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00058_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00031_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00114_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00064_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00027_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00090_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00015_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00095_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00023_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00090_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00094_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00095_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00071_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00122_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00057_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00036_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00011_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00115_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00122_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00082_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00114_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00040_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00059_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00062_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00082_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00014_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00056_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00038_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00125_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00076_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00007_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00026_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00009_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00115_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00034_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00120_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00123_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00008_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00055_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00062_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00041_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00065_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00019_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00101_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00010_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00120_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00077_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00050_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00057_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00058_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00036_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00072_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00053_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00061_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00056_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00111_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00077_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00015_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00022_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00107_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00115_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00030_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00112_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00071_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00031_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00074_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00069_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00020_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00012_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00040_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00074_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00015_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00121_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00042_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00119_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00058_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00082_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00078_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00061_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00118_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00120_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00038_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00017_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00124_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00080_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00032_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00060_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00105_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00073_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00065_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00039_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00027_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00043_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00080_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00056_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00011_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00008_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00054_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00092_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00004_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00103_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00017_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00067_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00045_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00019_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00068_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00003_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00033_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00063_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00072_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00011_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00076_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00006_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00010_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00032_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00062_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00020_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00076_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00003_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00053_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00008_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00048_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00093_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00084_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00026_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00010_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00001_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00070_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00087_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00118_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00041_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00123_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00026_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00064_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00083_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00076_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00018_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00012_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00039_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00065_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00014_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00124_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00121_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00067_Thaa_Middle_68.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00063_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00084_Thaa_Middle_76.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00020_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00092_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00028_Thaa_Middle_77.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Thaa_Middle/AHCR_00050_Thaa_Middle_69.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00011_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00020_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00051_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00072_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00013_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00051_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00012_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00029_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00114_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00017_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00005_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00092_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00079_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00027_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00074_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00119_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00057_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00006_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00061_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00041_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00106_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00115_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00003_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00050_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00083_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00010_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00047_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00019_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00006_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00081_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00079_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00069_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00017_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00066_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00062_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00109_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00040_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00074_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00053_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00043_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00095_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00028_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00048_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00090_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00076_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00081_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00012_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00110_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00099_Tah_Isolated_44.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00032_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00002_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00035_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00075_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00094_Tah_Isolated_36.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00113_Tah_Isolated_45.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00022_Tah_Isolated_37.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Tah_Isolated/AHCR_00051_Tah_Isolated_36.jpg
# ...
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00125_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00110_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00117_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00092_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00091_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00054_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00065_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00058_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00076_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00082_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00101_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00027_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00103_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00005_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00020_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00080_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00064_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00006_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00020_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00068_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00045_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00090_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00001_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00043_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00014_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00052_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00068_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00118_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00066_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00071_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00070_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00057_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00001_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00110_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00072_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00079_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00011_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00091_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00031_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00006_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00008_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00051_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00088_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00073_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00022_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00063_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00114_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00026_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00035_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00089_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00046_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00026_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00019_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00005_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00113_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00019_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00075_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00090_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00052_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00085_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00085_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00111_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00063_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00032_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00079_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00023_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00024_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00069_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00007_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00074_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00067_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00035_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00072_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00061_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00120_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00083_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00112_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00017_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00093_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00114_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00035_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00083_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00010_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00081_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00119_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00042_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00024_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00047_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00007_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00081_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00017_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00028_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00029_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00012_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00039_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00022_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00043_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00009_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00003_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00044_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00004_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00088_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00001_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00050_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00009_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00055_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00086_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00021_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00079_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00069_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00028_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00049_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00013_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00028_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00123_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00109_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00015_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00075_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00087_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00094_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00058_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00047_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00017_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00019_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00090_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00030_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00006_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00103_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00062_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00041_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00115_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00055_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00107_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00026_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00039_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00064_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00040_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00068_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00013_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00014_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00033_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00064_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00083_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00051_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00011_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00105_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00122_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00011_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00101_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00090_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00112_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00092_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00113_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00054_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00030_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00035_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00077_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00081_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00032_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00061_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00101_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00086_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00060_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00028_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00121_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00120_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00067_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00074_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00006_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00025_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00065_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00106_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00065_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00121_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00051_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00008_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00087_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00113_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00118_Yaa_End_31.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00076_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00064_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00036_Yaa_End_30.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00112_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00055_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00040_Yaa_End_22.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00106_Yaa_End_23.jpg
# Removed unreadable image: /content/HMBD_v1/Dataset/Yaa_End/AHCR_00053_Yaa_End_30.jpg
#
# ===== Cleanup Summary =====
# Total unreadable images removed: 17387
# Total empty directories removed: 0

# %%
# prompt: write out meta

logging.info("✅ Pipeline complete!")
for fname, miss in MISSING.items():
    logging.info(f"   • {fname}: {miss} unsupported glyphs")
logging.info(f" • CSV:    {CSV_PATH}")
logging.info(f" • Fonts:  {FONTS_DIR}")
logging.info(f" • Images: {IMAGES_DIR}")

# %%
# %% ──────────────────────────────────────────────────────────────
# !pip install -q --upgrade huggingface_hub pillow tqdm

import os, json, zipfile, random, shutil, logging
from pathlib import Path
from PIL import Image, ImageDraw, ImageFont, UnidentifiedImageError
from huggingface_hub import hf_hub_download, list_repo_files

# %% [markdown]
# # Data Generation

# %%
rm -rf data

# %%
# %% ──────────────────────────────────────────────────────────────
# ── dataset layout ──────────────────
OUT_ROOT   = Path("data")          # everything lands here
OUT_ROOT.mkdir(parents=True, exist_ok=True)
IMG_SZ     = 128
KEEP_N     = 100                                # images per glyph
RNG        = random.Random(2024)

# ── character selections ─────────────
ENGLISH  = [("0041","A","english character A"),
            ("0042","B","english character B"),
            ("0047","G","english character G")]

HINDI    = [("0915","ka","hindi character ka"),       # क
            ("0932","la","hindi character la"),       # ल
            ("0950","ga","hindi character ga")]       # ॐ

ARABIC   = [("0641","ف","arabic character faa","Faa_Isolated"),
            ("0642","ق","arabic character qaaf","Qaf_Isolated"),
            ("0645","م","arabic character meem","Mem_Isolated")]

# ── remote repos ─────────────────────
HF_EN = "Mayank022/English_Characters_Images"
HF_HI = "Mayank022/Devanagari-Characters-Image"

# ── HMBD + font info for Arabic ──────
HMBD_ROOT = Path("/content/HMBD_v1/Dataset")    # adjust if different
FONTS_DIR = Path("data_generation/fonts")       # four TTFs already downloaded
FONT_TTFS = ["NotoNaskhArabic[wght].ttf",
             "Amiri-Regular.ttf",
             "Lateef-Regular.ttf",
             "Harmattan-Regular.ttf"]

logging.basicConfig(level=logging.INFO,
                    format="%(levelname)s: %(message)s")

# %%
# %% ──────────────────────────────────────────────────────────────
def grab_character_images(repo_id: str,
                           char_tag: str,      # "A", "ka", …
                           unicode_hex: str,   # "0041", …
                           out_dir: Path,
                           keep: int = 100,
                           rng: random.Random | None = None,
                           img_sz: int = 128):
    """
    Copy ≤ *keep* 128×128 PNG/JPG images for one glyph from Mayank’s dataset.
    Handles both <char>.zip and extracted <char>/ folder layouts.
    """
    rng = rng or random
    out_dir.mkdir(parents=True, exist_ok=True)
    log = logging.getLogger(f"grab:{char_tag}")

    all_files = list_repo_files(repo_id, repo_type="dataset")
    log.info(f"[{char_tag}] {len(all_files)} entries in {repo_id}")

    # ── look for ZIP first ──
    zips = [f"{char_tag}.zip", f"{char_tag.upper()}.zip", f"{unicode_hex}.zip"]
    hit  = next((z for z in zips if z in all_files), None)

    if hit:                                            # ZIP branch
        zpath = hf_hub_download(repo_id, hit, repo_type="dataset")
        with zipfile.ZipFile(zpath) as zf:
            imgs = [m for m in zf.namelist()
                    if m.lower().endswith((".png", ".jpg", ".jpeg"))]
            rng.shuffle(imgs); imgs = imgs[:keep]
            log.info(f"  • {hit} → {len(imgs)} kept")
            for i, member in enumerate(imgs):
                with zf.open(member) as fh:
                    Image.open(fh).convert("L")\
                         .resize((img_sz, img_sz), Image.LANCZOS)\
                         .save(out_dir / f"{i:03d}.png")
        return

    # ── else: look for extracted folder ──
    prefixes = [f"{char_tag}/", f"{char_tag.upper()}/", f"{unicode_hex}/"]
    prefix   = next((p for p in prefixes if any(f.startswith(p) for f in all_files)), None)
    if not prefix:
        raise FileNotFoundError(f"No ZIP or folder for “{char_tag}” in {repo_id}")

    imgs = [f for f in all_files
            if f.startswith(prefix) and f.lower().endswith((".png",".jpg",".jpeg"))]
    rng.shuffle(imgs); imgs = imgs[:keep]
    log.info(f"  • folder {prefix} → {len(imgs)} kept")
    for i, remote in enumerate(imgs):
        local = hf_hub_download(repo_id, remote, repo_type="dataset")
        Image.open(local).convert("L")\
             .resize((img_sz, img_sz), Image.LANCZOS)\
             .save(out_dir / f"{i:03d}.png")

# %%
# %% ──────────────────────────────────────────────────────────────
SCRATCH = 256
def crop_hmbd(img: Image.Image) -> Image.Image:
    w,h = img.size
    s   = min(w,h)
    img = img.crop(((w-s)//2, (h-s)//2, (w+s)//2, (h+s)//2))
    return img.resize((IMG_SZ, IMG_SZ), Image.LANCZOS).convert("L")

def random_affine(im: Image.Image, rng=RNG) -> Image.Image:
    ang = rng.uniform(-7,7); dx,dy = rng.randint(-4,4), rng.randint(-4,4)
    return im.rotate(ang, expand=True, fillcolor=255)\
             .transform(im.size, Image.AFFINE, (1,0,dx, 0,1,dy), fillcolor=255)

def render_font(glyph, ft_path, rng=RNG):
    ft = ImageFont.truetype(str(ft_path), rng.randint(96,118))
    canvas = Image.new("L", (SCRATCH,SCRATCH), 255)
    ImageDraw.Draw(canvas).text((SCRATCH//2,SCRATCH//2), glyph,
                                font=ft, fill=0, anchor="mm")
    canvas = random_affine(canvas, rng)
    if not canvas.getbbox():                     # glyph missing in font
        return None
    g = canvas.crop(canvas.getbbox())
    sc = min(IMG_SZ/g.width, IMG_SZ/g.height)
    g = g.resize((int(g.width*sc), int(g.height*sc)), Image.LANCZOS)
    final = Image.new("L", (IMG_SZ,IMG_SZ), 255)
    final.paste(g, ((IMG_SZ-g.width)//2, (IMG_SZ-g.height)//2))
    return final

# %%
meta = []
english_codes = {t[0] for t in ENGLISH}      # {"0041","0042",…}

for uni, char_tag, cap in ENGLISH + HINDI:
    repo = HF_EN if uni in english_codes else HF_HI
    out  = OUT_ROOT / uni
    logging.info(f"{cap}: fetching 100 samples from {repo}")

    grab_character_images(repo, char_tag, uni, out, keep=KEEP_N)

    IMG_EXTS = {".png", ".jpg", ".jpeg"}

    for p in out.iterdir():
        if p.suffix.lower() not in IMG_EXTS or not p.is_file():
            continue                    # ← skip ZIPs, json, cache dirs, …
        meta.append({
            "Unicode":   uni,
            "Character": char_tag,
            "caption":   cap,
            "file_name": f"{uni}/{p.name}"
        })
# Out:
# 25.png:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# 230.png:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# 273.png:   0%|          | 0.00/539 [00:00<?, ?B/s]
# 212.png:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# 134.png:   0%|          | 0.00/984 [00:00<?, ?B/s]
# 265.png:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# 87.png:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# 190.png:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# 111.png:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# 285.png:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# 180.png:   0%|          | 0.00/989 [00:00<?, ?B/s]
# 145.png:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# 247.png:   0%|          | 0.00/978 [00:00<?, ?B/s]
# 138.png:   0%|          | 0.00/856 [00:00<?, ?B/s]
# 260.png:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# 228.png:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# 100.png:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# 11.png:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# 78.png:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# 289.png:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# 303.png:   0%|          | 0.00/983 [00:00<?, ?B/s]
# 5.png:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# 8.png:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# 57.png:   0%|          | 0.00/1.30k [00:00<?, ?B/s]
# 54.png:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# 12.png:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# 278.png:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# 225.png:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# 219.png:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# 185.png:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# 60.png:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# 126.png:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# 199.png:   0%|          | 0.00/982 [00:00<?, ?B/s]
# 148.png:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# 82.png:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# 36.png:   0%|          | 0.00/963 [00:00<?, ?B/s]
# 157.png:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# 106.png:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# 123.png:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# 215.png:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# 150.png:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# 125.png:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# 234.png:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# 301.png:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# 40.png:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# 201.png:   0%|          | 0.00/932 [00:00<?, ?B/s]
# 30.png:   0%|          | 0.00/905 [00:00<?, ?B/s]
# 172.png:   0%|          | 0.00/865 [00:00<?, ?B/s]
# 105.png:   0%|          | 0.00/950 [00:00<?, ?B/s]
# 223.png:   0%|          | 0.00/953 [00:00<?, ?B/s]
# 260.png:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# 234.png:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# 254.png:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# 175.png:   0%|          | 0.00/846 [00:00<?, ?B/s]
# 290.png:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# 230.png:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# 203.png:   0%|          | 0.00/927 [00:00<?, ?B/s]
# 182.png:   0%|          | 0.00/953 [00:00<?, ?B/s]
# 293.png:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 191.png:   0%|          | 0.00/839 [00:00<?, ?B/s]
# 237.png:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# 236.png:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# 180.png:   0%|          | 0.00/833 [00:00<?, ?B/s]
# 287.png:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# 28.png:   0%|          | 0.00/881 [00:00<?, ?B/s]
# 66.png:   0%|          | 0.00/935 [00:00<?, ?B/s]
# 130.png:   0%|          | 0.00/727 [00:00<?, ?B/s]
# 94.png:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# 288.png:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# 282.png:   0%|          | 0.00/530 [00:00<?, ?B/s]
# 109.png:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# 292.png:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# 250.png:   0%|          | 0.00/779 [00:00<?, ?B/s]
# 141.png:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# 225.png:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# 72.png:   0%|          | 0.00/805 [00:00<?, ?B/s]
# 266.png:   0%|          | 0.00/819 [00:00<?, ?B/s]
# 114.png:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# 80.png:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# 242.png:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# 171.png:   0%|          | 0.00/947 [00:00<?, ?B/s]
# 283.png:   0%|          | 0.00/515 [00:00<?, ?B/s]
# 305.png:   0%|          | 0.00/971 [00:00<?, ?B/s]
# 211.png:   0%|          | 0.00/853 [00:00<?, ?B/s]
# 6.png:   0%|          | 0.00/869 [00:00<?, ?B/s]
# 195.png:   0%|          | 0.00/897 [00:00<?, ?B/s]
# 44.png:   0%|          | 0.00/892 [00:00<?, ?B/s]
# 244.png:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# 224.png:   0%|          | 0.00/444 [00:00<?, ?B/s]
# 99.png:   0%|          | 0.00/402 [00:00<?, ?B/s]
# 282.png:   0%|          | 0.00/547 [00:00<?, ?B/s]
# 210.png:   0%|          | 0.00/647 [00:00<?, ?B/s]
# 234.png:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# 71.png:   0%|          | 0.00/478 [00:00<?, ?B/s]
# 176.png:   0%|          | 0.00/374 [00:00<?, ?B/s]
# 75.png:   0%|          | 0.00/302 [00:00<?, ?B/s]
# 276.png:   0%|          | 0.00/820 [00:00<?, ?B/s]
# 114.png:   0%|          | 0.00/676 [00:00<?, ?B/s]
# 88.png:   0%|          | 0.00/381 [00:00<?, ?B/s]
# 181.png:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 223.png:   0%|          | 0.00/384 [00:00<?, ?B/s]
# 108.png:   0%|          | 0.00/796 [00:00<?, ?B/s]
# 59.png:   0%|          | 0.00/404 [00:00<?, ?B/s]
# 164.png:   0%|          | 0.00/630 [00:00<?, ?B/s]
# 173.png:   0%|          | 0.00/424 [00:00<?, ?B/s]
# 245.png:   0%|          | 0.00/482 [00:00<?, ?B/s]
# 152.png:   0%|          | 0.00/546 [00:00<?, ?B/s]
# 180.png:   0%|          | 0.00/330 [00:00<?, ?B/s]
# 266.png:   0%|          | 0.00/428 [00:00<?, ?B/s]
# 195.png:   0%|          | 0.00/611 [00:00<?, ?B/s]
# 47.png:   0%|          | 0.00/665 [00:00<?, ?B/s]
# 79.png:   0%|          | 0.00/750 [00:00<?, ?B/s]
# 252.png:   0%|          | 0.00/450 [00:00<?, ?B/s]
# 198.png:   0%|          | 0.00/574 [00:00<?, ?B/s]
# 214.png:   0%|          | 0.00/545 [00:00<?, ?B/s]
# 54.png:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# 216.png:   0%|          | 0.00/432 [00:00<?, ?B/s]
# 8.png:   0%|          | 0.00/361 [00:00<?, ?B/s]
# 199.png:   0%|          | 0.00/523 [00:00<?, ?B/s]
# 250.png:   0%|          | 0.00/406 [00:00<?, ?B/s]
# 219.png:   0%|          | 0.00/563 [00:00<?, ?B/s]
# 104.png:   0%|          | 0.00/342 [00:00<?, ?B/s]
# 89.png:   0%|          | 0.00/345 [00:00<?, ?B/s]
# 217.png:   0%|          | 0.00/469 [00:00<?, ?B/s]
# 277.png:   0%|          | 0.00/726 [00:00<?, ?B/s]
# 187.png:   0%|          | 0.00/509 [00:00<?, ?B/s]
# 134.png:   0%|          | 0.00/465 [00:00<?, ?B/s]
# 5.png:   0%|          | 0.00/448 [00:00<?, ?B/s]
# 40.png:   0%|          | 0.00/635 [00:00<?, ?B/s]
# 168.png:   0%|          | 0.00/637 [00:00<?, ?B/s]

# %% [markdown]
# # Arabic

# %%
# %% ──────────────────────────────────────────────────────────────
font_paths = [FONTS_DIR/f for f in FONT_TTFS]
for p in font_paths:
    if not p.exists():
        raise FileNotFoundError(f"Font missing → {p}")

for uni, glyph, cap, sub in ARABIC:
    out_dir = OUT_ROOT/uni
    out_dir.mkdir(exist_ok=True)
    logging.info(f"{cap}: processing HMBD + fonts")

    # -- HMBD real samples --
    src = HMBD_ROOT/sub
    files = [p for p in src.iterdir() if p.suffix.lower() in {".png",".jpg",".jpeg"}]
    RNG.shuffle(files)
    for i, f in enumerate(files[:KEEP_N]):
        try:
            img = crop_hmbd(Image.open(f))
            img.save(out_dir/f"{i:03d}.png")
            meta.append({"Unicode":uni,
                         "Character":glyph,
                         "caption":cap,
                         "file_name":f"{uni}/{i:03d}.png"})
        except Exception as e:
            logging.warning(f"skip {f} → {e}")

    # -- synthetic extra (10) --
    j = 0
    while j < KEEP_N:
        img = render_font(glyph, RNG.choice(font_paths))
        if img:
            if RNG.random() < 0.4:
                img = img.rotate(RNG.uniform(-10,10), fillcolor=255
            fname = f"font_{j:02d}.png"
            img.save(out_dir/fname)
            meta.append({"Unicode":uni,
                         "Character":glyph,
                         "caption":cap,
                         "file_name":f"{uni}/{fname}"})
            j += 1
# Out:
#   File "<ipython-input-38-bc51a5fdd2ef>", line 33
#     img = img.rotate(RNG.uniform(-10,10), fillcolor=255
#                     ^
# SyntaxError: '(' was never closed

# %%
# %% ──────────────────────────────────────────────────────────────
MAYAN_DIR = Path("/content/drive/MyDrive/EMNLP/mayan_glyphs_100")   # ← upload your images here first
if MAYAN_DIR.exists():
    uni     = "XXXX"             # change to actual code-point if known
    caption = "MAM" # https://mayaglyphs.org/ 1518 MAM or grandfather
    for i, p in enumerate(sorted(MAYAN_DIR.iterdir())[:(KEEP_N)]):
        fname = f"{i:03d}.png"
        (OUT_ROOT/uni).mkdir(parents=True, exist_ok=True)
        shutil.copy2(p, OUT_ROOT/uni/fname)
        meta.append({"Unicode":uni,
                     "Character":"MAM_Grandfather",
                     "caption":caption,
                     "file_name":f"{uni}/{fname}"})

# %%
# %% ──────────────────────────────────────────────────────────────
meta_path = OUT_ROOT/"metadata.jsonl"
with meta_path.open("w", encoding="utf-8") as fh:
    for rec in meta:
        fh.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"✅  wrote {len(meta):,} lines → {meta_path}")
# Out:
# ✅  wrote 600 lines → data/metadata.jsonl

# %%
# %% ──────────────────────────────────────────────────────────────
from collections import Counter, defaultdict
cnt = Counter(rec["caption"] for rec in meta)
print("\nImages per caption:")
for k,v in cnt.items():
    print(f"{k:<5}: {v}")

subdirs = defaultdict(int)
for rec in meta:
    subdirs[rec["Unicode"]] += 1
# Out:
# Images per caption:
# english character A: 100
# english character B: 100
# english character G: 100
# hindi character ka: 100
# hindi character la: 100
# hindi character ga: 100

# %% [markdown]
# # T5

# %%
import torch
import transformers
from typing import List
from transformers import T5Tokenizer, T5EncoderModel, T5Config
from einops import rearrange

transformers.logging.set_verbosity_error()

def exists(val):
    return val is not None

def default(val, d):
    if exists(val):
        return val
    return d() if callable(d) else d

# config

MAX_LENGTH = 256

DEFAULT_T5_NAME = 'google/t5-v1_1-base'

T5_CONFIGS = {}

# singleton globals

def get_tokenizer(name):
    tokenizer = T5Tokenizer.from_pretrained(name, model_max_length=MAX_LENGTH)
    return tokenizer

def get_model(name):
    model = T5EncoderModel.from_pretrained(name)
    return model

def get_model_and_tokenizer(name):
    global T5_CONFIGS

    if name not in T5_CONFIGS:
        T5_CONFIGS[name] = dict()
    if "model" not in T5_CONFIGS[name]:
        T5_CONFIGS[name]["model"] = get_model(name)
    if "tokenizer" not in T5_CONFIGS[name]:
        T5_CONFIGS[name]["tokenizer"] = get_tokenizer(name)

    return T5_CONFIGS[name]['model'], T5_CONFIGS[name]['tokenizer']

def get_encoded_dim(name):
    if name not in T5_CONFIGS:
        # avoids loading the model if we only want to get the dim
        config = T5Config.from_pretrained(name)
        T5_CONFIGS[name] = dict(config=config)
    elif "config" in T5_CONFIGS[name]:
        config = T5_CONFIGS[name]["config"]
    elif "model" in T5_CONFIGS[name]:
        config = T5_CONFIGS[name]["model"].config
    else:
        assert False
    return config.d_model

# encoding text

def t5_tokenize(
    texts: List[str],
    name = DEFAULT_T5_NAME
):
    t5, tokenizer = get_model_and_tokenizer(name)

    if torch.cuda.is_available():
        t5 = t5.cuda()

    device = next(t5.parameters()).device

    encoded = tokenizer.batch_encode_plus(
        texts,
        return_tensors = "pt",
        padding = 'longest',
        max_length = MAX_LENGTH,
        truncation = True
    )

    input_ids = encoded.input_ids.to(device)
    attn_mask = encoded.attention_mask.to(device)
    return input_ids, attn_mask

def t5_encode_tokenized_text(
    token_ids,
    attn_mask = None,
    pad_id = None,
    name = DEFAULT_T5_NAME
):
    assert exists(attn_mask) or exists(pad_id)
    t5, _ = get_model_and_tokenizer(name)

    attn_mask = default(attn_mask, lambda: (token_ids != pad_id).long())

    t5.eval()

    with torch.no_grad():
        output = t5(input_ids = token_ids, attention_mask = attn_mask)
        encoded_text = output.last_hidden_state.detach()

    attn_mask = attn_mask.bool()

    encoded_text = encoded_text.masked_fill(~rearrange(attn_mask, '... -> ... 1'), 0.) # just force all embeddings that is padding to be equal to 0.
    return encoded_text

def t5_encode_text(
    texts: List[str],
    name = DEFAULT_T5_NAME,
    return_attn_mask = False
):
    token_ids, attn_mask = t5_tokenize(texts, name = name)
    encoded_text = t5_encode_tokenized_text(token_ids, attn_mask = attn_mask, name = name)

    if return_attn_mask:
        attn_mask = attn_mask.bool()
        return encoded_text, attn_mask

    return encoded_text

# %% [markdown]
# # Utils

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
from torch.nn.utils.rnn import pad_sequence

from PIL import Image, ImageDraw, ImageFont

from diffusers.pipelines.pipeline_utils import DiffusionPipeline, ImagePipelineOutput
from typing import List, Optional, Tuple, Union
from diffusers.utils.torch_utils import randn_tensor


# Collator adjusted for local dataset
class Collator:
    def __init__(self, image_size, text_label, image_label, name, channels):
        self.text_label = text_label
        self.image_label = image_label
        self.name = name
        self.channels = channels
        self.transform = T.Compose([
            T.Resize((image_size, image_size)),
            T.ToTensor(),
        ])

    def __call__(self, batch):
        texts = []
        masks = []
        images = []
        for item in batch:
            try:
                # Load image from local file
                image_path = 'data/'+item[self.image_label]  # Assuming this is a path to the image file
                with Image.open(image_path) as img:
                    image = self.transform(img.convert(self.channels))
            except Exception as e:
                print(f"Failed to process image {image_path}: {e}")
                continue

            # Encode the text
            text, mask = t5_encode_text(
                [item[self.text_label]],
                name=self.name,
                return_attn_mask=True
                )
            texts.append(torch.squeeze(text))
            masks.append(torch.squeeze(mask))
            images.append(image)

        if len(texts) == 0:
            return None

        # Are these strictly necessary?
        texts = pad_sequence(texts, True)
        masks = pad_sequence(masks, True)

        newbatch = []
        for i in range(len(texts)):
            newbatch.append((images[i], texts[i], masks[i]))

        return torch.utils.data.dataloader.default_collate(newbatch)


class GlyffuserPipeline(DiffusionPipeline):
    r'''
    Pipeline for text-to-image generation from the glyffuser model

    Parameters:
        unet (['UNet2DConditionModel'])
        scheduler (['SchedulerMixin'])
        text_encoder (['TextEncoder']) - T5 small
    '''
    def __init__(self, unet, scheduler):
        super().__init__()
        self.register_modules(
            unet=unet,
            scheduler=scheduler,
            )

    @torch.no_grad()
    def __call__(
        self,
        texts: List[str],
        text_encoder: str = "google-t5/t5-small",
        batch_size: int = 1,
        generator: Optional[Union[torch.Generator, List[torch.Generator]]] = None,
        num_inference_steps: int = 1000,
        output_type: Optional[str] = "pil",
        return_dict: bool = True,
    ) -> Union[ImagePipelineOutput, Tuple]:
        '''
        Docstring
        '''
        # Get text embeddings
        # Encode the text
        # text_embeddings = []
        # for text in texts:
        #     embedding = t5.t5_encode_text(text, name=text_encoder)
        #     text_embeddings.append(torch.squeeze(embedding))
        # text_embeddings = pad_sequence(text_embeddings, True)

        batch_size = len(texts)

        text_embeddings, masks = t5_encode_text(texts, name=text_encoder, return_attn_mask=True)

        # Sample gaussian noise to begin loop
        if isinstance(self.unet.config.sample_size, int):
            image_shape = (
                batch_size,
                self.unet.config.in_channels,
                self.unet.config.sample_size,
                self.unet.config.sample_size,
            )
        else:
            image_shape = (batch_size, self.unet.config.in_channels, *self.unet.config.sample_size)


        # if self.device.type == "mps": # MPS is apple silicon
        #     # randn does not work reproducibly on mps
        #     image = randn_tensor(image_shape, generator=generator)
        #     image = image.to(self.device)
        # else:
        image = randn_tensor(image_shape, generator=generator, device=self.device)

        # set step values
        self.scheduler.set_timesteps(num_inference_steps)

        for t in self.progress_bar(self.scheduler.timesteps):
            # 1. predict noise model_output
            model_output = self.unet(
                image,
                t,
                encoder_hidden_states=text_embeddings, # Add text encoding input
                encoder_attention_mask=masks, # Add attention mask
                return_dict=False
                )[0] # <-- sample is an attribute of the BaseOutClass of type torch.FloatTensor

            # 2. compute previous image: x_t -> x_t-1
            image = self.scheduler.step(model_output, t, image, generator=generator, return_dict=False)[0]

        # image = (image / 2 + 0.5).clamp(0, 1)
        image = image.clamp(0, 1) # No need to rescale for HF yuewu/glyffuser
        image = image.cpu().permute(0, 2, 3, 1).numpy()
        if output_type == "pil":
            image = self.numpy_to_pil(image)

        if not return_dict:
            return (image,)

        return ImagePipelineOutput(images=image)

def make_grid(images, rows, cols):
    w, h = images[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    for i, image in enumerate(images):
        grid.paste(image, box=(i%cols*w, i//cols*h))
    return grid

def evaluate(config, epoch, texts, pipeline):
    images = pipeline(
        texts,
        batch_size = config.eval_batch_size,
        generator=torch.Generator(device='cpu').manual_seed(config.seed), # Generator must be on CPU for sampling during training
    ).images

    # Make a grid out of the images
    image_grid = make_grid(images, rows=4, cols=4)

    # Save the images
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    image_grid.save(f"{test_dir}/{epoch:04d}.png")

def make_labeled_grid(images, prompt, steps, font_path=None, font_size=20, margin=10):
    assert len(images) == len(steps), "The number of images must match the number of steps"

    w, h = images[0].size
    font = ImageFont.truetype(font_path, font_size) if font_path else ImageFont.load_default()

    # Calculate the height of the grid including the margin for text
    total_height = h + margin + font_size
    total_width = w * len(images)
    grid_height = total_height + margin + font_size  # Add extra margin for the prompt
    grid = Image.new('RGB', size=(total_width, grid_height), color=(255, 255, 255))

    # Draw the text prompt at the top
    draw = ImageDraw.Draw(grid)
    prompt_text = f"Prompt: \"{prompt}\""
    prompt_width, prompt_height = draw.textbbox((0, 0), prompt_text, font=font)[2:4]
    prompt_x = (total_width - prompt_width) / 2
    prompt_y = margin / 2
    draw.text((prompt_x, prompt_y), prompt_text, fill="black", font=font)

    for i, (image, step) in enumerate(zip(images, steps)):
        # Calculate position to paste the image
        x = i * w
        y = margin + font_size

        # Paste the image
        grid.paste(image, box=(x, y))

        # Draw the step text
        step_text = f"Steps: {step}"
        text_width, text_height = draw.textbbox((0, 0), step_text, font=font)[2:4]
        text_x = x + (w - text_width) / 2
        text_y = y + h + margin / 2 - 8
        draw.text((text_x, text_y), step_text, fill="black", font=font)

    return grid

# %% [markdown]
# # Conditional Glyffuser

# %% [markdown]
# ### Define training parameters
# We add text_encoder and encoder_dim parameters to the config. The batch size is also smaller due to the larger size of the conditional model.

# %%
import os, numpy as np, matplotlib.pyplot as plt, torch, torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.nn.functional as F
from datasets import load_dataset
from diffusers.optimization import get_cosine_schedule_with_warmup
from diffusers import UNet2DConditionModel, DDPMScheduler
from accelerate import Accelerator
from tqdm.auto import tqdm
import os
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass
from diffusers import DPMSolverMultistepScheduler
from torchmetrics.image.fid import FrechetInceptionDistance

# %%
@dataclass
class TrainingConfig:
    image_size = 128  # the generated image resolution
    train_batch_size = 16
    eval_batch_size = 16  # how many images to sample during evaluation
    num_epochs = 800
    gradient_accumulation_steps = 1
    learning_rate = 1e-4
    lr_warmup_steps = 500
    save_image_epochs = 25
    save_model_epochs = 30
    mixed_precision = "fp16"  # `no` for float32, `fp16` for automatic mixed precision
    output_dir = "/content/drive/MyDrive/EMNLP/multilingual_diffuser/more_data_arabic_mayan"
    overwrite_output_dir = True  # overwrite the old model when re-running the notebook
    text_encoder = "google-t5/t5-small"
    encoder_dim = 512
    seed = 0

config = TrainingConfig()

# %%
import torch
from torch.utils.data import DataLoader
import torch.nn.functional as F
from datasets import load_dataset
from diffusers.optimization import get_cosine_schedule_with_warmup
from diffusers import UNet2DConditionModel, DDPMScheduler
from accelerate import Accelerator
from tqdm.auto import tqdm
import os
from torchvision.utils import save_image  # optional helper
import numpy as np
import matplotlib.pyplot as plt


def train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler):
    # Initialize accelerator and tensorboard logging
    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard",
        project_dir=os.path.join(config.output_dir, "logs")
    )
    if accelerator.is_main_process:

        if config.output_dir is not None:
            os.makedirs(config.output_dir, exist_ok=True)
        sample_dir = os.path.join(config.output_dir, "samples")
        os.makedirs(sample_dir, exist_ok=True)
        accelerator.init_trackers("train_example")

    # Prepare everything for accelerator
    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )

    global_step = 0
    loss_hist, kl_hist = [], []

    # Now you train the model
    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            clean_images = batch[0]
            noise = torch.randn(clean_images.shape).to(clean_images.device)
            bs = clean_images.shape[0]
            timesteps = torch.randint(0, noise_scheduler.num_train_timesteps, (bs,), device=clean_images.device).long()
            noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)
            with accelerator.accumulate(model):
                noise_pred = model(
                    noisy_images,
                    timesteps,
                    encoder_hidden_states=batch[1],
                    return_dict=False
                    )[0]
                loss = F.mse_loss(noise_pred, noise)

                # --- KL divergence between N(noise_pred, I) and N(0, I)
                kl_loss = 0.5 * (noise_pred - noise).pow(2).mean()   # <── NEW
                loss_hist.append(loss.item())                        # <── NEW
                kl_hist.append(kl_loss.item())

                accelerator.backward(loss)
                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()

            progress_bar.update(1)

            logs = {
                  "loss": loss.item(),
                  "kl_loss": kl_loss.item(),       # <── NEW (TensorBoard)
                  "lr": lr_scheduler.get_last_lr()[0],
                  "step": global_step,
                    }

            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)
            global_step += 1


        if accelerator.is_main_process and (
            (epoch + 1) % config.save_image_epochs == 0
            or epoch == config.num_epochs - 1
        ):
            pipe = GlyffuserPipeline(
                unet=accelerator.unwrap_model(model),
                scheduler=inference_scheduler
            ).to(accelerator.device)

            texts = [
                      "A", "B", "G",          # Latin
                      "faa", "qaaf", "meem",  # Arabic
                      "ka", "la", "ga",        # Devanagari
                      "MAM"
                    ]
            pipe.scheduler.set_timesteps(25)
            images = [pipe(t, num_inference_steps=25).images[0] for t in texts]

            # ----- make grid & save individual PNGs -----
            stack = []
            for cap, im in zip(texts, images):
                arr = np.array(im)
                if arr.ndim == 2:          # grayscale -> (H,W,1)
                    arr = arr[..., None]
                tensor = torch.from_numpy(arr).permute(2, 0, 1).float() / 255
                stack.append(tensor)
                im.save(os.path.join(sample_dir, f"epoch_{epoch:03d}_{cap}.png"))

            grid = torch.stack(stack)      # (N,C,H,W)
            save_image(grid,
                       os.path.join(sample_dir, f"grid_{epoch:03d}.png"),
                       nrow=len(texts))

            # save checkpoint
            pipe.save_pretrained(os.path.join(
                config.output_dir, f"checkpoint-{epoch:03d}"
            ))
            del pipe

    # ─── final loss curves ─────────────────────────────────────────
    if accelerator.is_main_process:
        plt.figure()
        plt.plot(loss_hist, label="MSE loss")
        plt.plot(kl_hist,   label="KL loss (½·MSE)")
        plt.yscale("log")
        plt.xlabel("training step")
        plt.ylabel("loss")
        plt.legend()
        plot_path = os.path.join(config.output_dir, "loss_curves_final.png")
        plt.savefig(plot_path, dpi=150, bbox_inches="tight")
        plt.close()
        print(f"Saved final loss curves → {plot_path}")

# %% [markdown]
# We add a collator which helps the dataloader pass text embeddings to the model during training

# %%
from diffusers import DPMSolverMultistepScheduler

# Define collator
collator = Collator(
    image_size=128,
    text_label='caption',  # This is where you specify which field to use for text
    image_label='file_name',
    name=config.text_encoder,
    channels='L'
)

# Define data source
dataset = load_dataset("json", data_files="data/metadata.jsonl")
train_dataloader = DataLoader(dataset['train'], batch_size=config.train_batch_size, collate_fn=collator, shuffle=True)

# Define model
model = UNet2DConditionModel(
    sample_size=config.image_size,  # the target image resolution
    in_channels=1,  # the number of input channels, 1 for RGB images
    out_channels=1,  # the number of output channels
    layers_per_block=2,  # how many ResNet layers to use per UNet block
    # block_out_channels=(128, 128, 256, 256, 512, 512),  # the number of output channels for each UNet block
    block_out_channels=(128, 256, 512, 512),  # the number of output channels for each UNet block

    addition_embed_type="text", # Make it conditional
    cross_attention_dim=config.encoder_dim,
    encoder_hid_dim=config.encoder_dim,  # the hidden dimension of the encoder
    encoder_hid_dim_type="text_proj",  # the hidden dimension of the encoder
    down_block_types=(
        "DownBlock2D",
        "DownBlock2D",
        "CrossAttnDownBlock2D",
        "DownBlock2D"
    ),
    up_block_types=(
        "UpBlock2D",
        "CrossAttnUpBlock2D",
        "UpBlock2D",
        "UpBlock2D"
    ),
)

# Define optimizers and schedulers
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
inference_scheduler = DPMSolverMultistepScheduler()
optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)
lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)
# Check model parameters
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_params:,} total parameters.')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# 130,790,657 total parameters.

# %% [markdown]
# Pass everything to accelerate and run the training loop

# %%
from accelerate import notebook_launcher

args = (config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
notebook_launcher(train_loop, args, num_processes=1)
# Out:
# Launching training on one GPU.
#   0%|          | 0/63 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/diffusers/configuration_utils.py:141: FutureWarning: Accessing config attribute `num_train_timesteps` directly via 'DDPMScheduler' object attribute is deprecated. Please access 'num_train_timesteps' over 'DDPMScheduler's config object instead, e.g. 'scheduler.config.num_train_timesteps'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-81a86052503d> in <cell line: 0>()
#       2
#       3 args = (config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
# ----> 4 notebook_launcher(train_loop, args, num_processes=1)
#
# /usr/local/lib/python3.11/dist-packages/accelerate/launchers.py in notebook_launcher(function, args, num_processes, mixed_precision, use_port, master_addr, node_rank, num_nodes, rdzv_backend, rdzv_endpoint, rdzv_conf, rdzv_id, max_restarts, monitor_interval, log_line_prefix_template)
#     263             else:
#     264                 print("Launching training on CPU.")
# --> 265             function(*args)
#     266
#     267
#
# <ipython-input-92-ad7aac0f3044> in train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
#      49             noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)
#      50             with accelerator.accumulate(model):
# ---> 51                 noise_pred = model(
#      52                     noisy_images,
#      53                     timesteps,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     812
#     813     def forward(*args, **kwargs):
# --> 814         return model_forward(*args, **kwargs)
#     815
#     816     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     800
#     801     def __call__(self, *args, **kwargs):
# --> 802         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     803
#     804     def __getstate__(self):
#
# /usr/local/lib/python3.11/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      42     def decorate_autocast(*args, **kwargs):
#      43         with autocast_instance:
# ---> 44             return func(*args, **kwargs)
#      45
#      46     decorate_autocast.__script_unsupported = "@autocast() decorator is not supported in script mode"  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/unets/unet_2d_condition.py in forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1212                     additional_residuals["additional_residuals"] = down_intrablock_additional_residuals.pop(0)
#    1213
# -> 1214                 sample, res_samples = downsample_block(
#    1215                     hidden_states=sample,
#    1216                     temb=emb,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/unets/unet_2d_blocks.py in forward(self, hidden_states, temb, encoder_hidden_states, attention_mask, cross_attention_kwargs, encoder_attention_mask, additional_residuals)
#    1268             else:
#    1269                 hidden_states = resnet(hidden_states, temb)
# -> 1270                 hidden_states = attn(
#    1271                     hidden_states,
#    1272                     encoder_hidden_states=encoder_hidden_states,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/transformers/transformer_2d.py in forward(self, hidden_states, encoder_hidden_states, timestep, added_cond_kwargs, class_labels, cross_attention_kwargs, attention_mask, encoder_attention_mask, return_dict)
#     425                 )
#     426             else:
# --> 427                 hidden_states = block(
#     428                     hidden_states,
#     429                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/attention.py in forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, timestep, cross_attention_kwargs, class_labels, added_cond_kwargs)
#     512         gligen_kwargs = cross_attention_kwargs.pop("gligen", None)
#     513
# --> 514         attn_output = self.attn1(
#     515             norm_hidden_states,
#     516             encoder_hidden_states=encoder_hidden_states if self.only_cross_attention else None,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/attention_processor.py in forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     603         cross_attention_kwargs = {k: w for k, w in cross_attention_kwargs.items() if k in attn_parameters}
#     604
# --> 605         return self.processor(
#     606             self,
#     607             hidden_states,
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/attention_processor.py in __call__(self, attn, hidden_states, encoder_hidden_states, attention_mask, temb, *args, **kwargs)
#    3311         # the output of sdp = (batch, num_heads, seq_len, head_dim)
#    3312         # TODO: add support for attn.scale when we move to Torch 2.1
# -> 3313         hidden_states = F.scaled_dot_product_attention(
#    3314             query, key, value, attn_mask=attention_mask, dropout_p=0.0, is_causal=False
#    3315         )
#
# KeyboardInterrupt:

# %%
from diffusers import DPMSolverMultistepScheduler
import torch

# Initialize the model pipeline
pipeline = GlyffuserPipeline.from_pretrained(f"{config.output_dir}/checkpoint-199").to("cuda")
pipeline.scheduler = DPMSolverMultistepScheduler()

texts = ['X']  # Your text prompt
num_inference_steps_list = [1, 2, 3, 5, 10, 20, 50, 100]  # List of different num_inference_steps values

images = []

# Generate images for each value in num_inference_steps_list
for num_steps in num_inference_steps_list:
    generated_images = pipeline(
        texts,
        batch_size=1,  # Generate one image at a time for each step
        generator=torch.Generator(device='cuda').manual_seed(42),  # Generator can be on GPU here
        num_inference_steps=num_steps
    ).images
    images.append(generated_images[0])  # Append the generated image

# Create the labeled grid
image_grid = make_labeled_grid(images, texts[0], num_inference_steps_list, font_size=30, margin=20)
image_grid

# Save the image grid
# image_grid.save(f"inference example.png") # Uncomment to save

# %%
from pathlib import Path
import torch, numpy as np, math
from diffusers import DPMSolverMultistepScheduler
from PIL import Image, ImageDraw, ImageFont

# ───────────────── helper: labelled grid ──────────────────────────
def make_labeled_grid(images, caption, steps, font_size=24, margin=8):
    """Return a PIL.Image that shows `images` in a row with step labels."""
    w, h = images[0].size
    font = ImageFont.load_default()
    total_w = w * len(images)
    total_h = h + font_size + margin

    grid = Image.new("RGB", (total_w, total_h), "white")
    draw = ImageDraw.Draw(grid)

    for i, (img, s) in enumerate(zip(images, steps)):
        grid.paste(img, (i * w, 0))
        txt = f"{s}"
        tw, th = draw.textbbox((0, 0), txt, font=font)[2:]
        tx = i * w + (w - tw) // 2
        draw.text((tx, h + margin // 2), txt, fill="black", font=font)

    # title (caption) centred on top
    title_w, _ = draw.textbbox((0, 0), caption, font=font)[2:]
    draw.text(((total_w - title_w) // 2, -margin // 2), caption, fill="black", font=font)
    return grid

# ───────────────── config  ────────────────────────────────────────
ckpt_dir   = f"{config.output_dir}/checkpoint-199"   # <-- latest trained ckpt
out_root   = Path(config.output_dir) / "inference"
out_root.mkdir(exist_ok=True)

captions   = [          # 15 glyphs (5×Latin,5×Arabic,5×Devanagari)
    "A","B","W","D","G",
    "faa","qaaf","ghayn","laam","meem",
    "ka","la","om","ga","ma"
]
num_steps  = [1, 2, 3, 5, 10, 20, 50, 100]
seed       = 42
device     = "cuda"

# ───────────────── pipeline  ──────────────────────────────────────
pipe = GlyffuserPipeline.from_pretrained(ckpt_dir).to(device)
pipe.scheduler = DPMSolverMultistepScheduler()

# ───────────────── generation  ────────────────────────────────────
mega_rows = []                # for optional mega-grid
for cap in captions:
    subdir = out_root / cap.replace(" ", "_")
    subdir.mkdir(exist_ok=True)

    imgs_for_grid = []
    for n in num_steps:
        img = pipe(
            cap,
            num_inference_steps=n,
            batch_size=1,
            generator=torch.Generator(device).manual_seed(seed),
        ).images[0]
        img.save(subdir / f"{cap}_{n:03}.png")
        imgs_for_grid.append(img)

    # grid for this caption
    g = make_labeled_grid(imgs_for_grid, cap, num_steps)
    g.save(subdir / f"{cap}_grid.png")
    mega_rows.append(imgs_for_grid[-1])     # take the *final* step for mega grid

# ───────────────── optional mega-grid (all captions)  ─────────────
cols = 5
rows = math.ceil(len(mega_rows) / cols)
w, h = mega_rows[0].size
mega = Image.new("RGB", (w * cols, h * rows), "white")
for idx, img in enumerate(mega_rows):
    r, c = divmod(idx, cols)
    mega.paste(img, (c * w, r * h))
mega.save(out_root / "mega_grid.png")

print("✅  Inference images saved to:", out_root)
